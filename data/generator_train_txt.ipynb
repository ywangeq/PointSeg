# %%
import os

# %%
root_mems = 'ImageSet/train_mems.txt'

# %%
file_object = open(root_mems,'w')

# %%
for data in os.listdir('Mems'):
    print 'path',data
    for name in os.listdir('Mems'+'/'+data):  
        root= data+'/'+name[:-4]
        print root
        print 'data',data
        print 'name',name[:-4]
        file_object.write(root)
        file_object.write('\n')
# Out:
# path 2011_09_26_drive_0001_sync
# 2011_09_26_drive_0001_sync/0000000065
# data 2011_09_26_drive_0001_sync
# name 0000000065
# 2011_09_26_drive_0001_sync/0000000007
# data 2011_09_26_drive_0001_sync
# name 0000000007
# 2011_09_26_drive_0001_sync/0000000092
# data 2011_09_26_drive_0001_sync
# name 0000000092
# 2011_09_26_drive_0001_sync/0000000033
# data 2011_09_26_drive_0001_sync
# name 0000000033
# 2011_09_26_drive_0001_sync/0000000097
# data 2011_09_26_drive_0001_sync
# name 0000000097
# 2011_09_26_drive_0001_sync/0000000021
# data 2011_09_26_drive_0001_sync
# name 0000000021
# 2011_09_26_drive_0001_sync/0000000053
# data 2011_09_26_drive_0001_sync
# name 0000000053
# 2011_09_26_drive_0001_sync/0000000098
# data 2011_09_26_drive_0001_sync
# name 0000000098
# 2011_09_26_drive_0001_sync/0000000093
# data 2011_09_26_drive_0001_sync
# name 0000000093
# 2011_09_26_drive_0001_sync/0000000100
# data 2011_09_26_drive_0001_sync
# name 0000000100
# 2011_09_26_drive_0001_sync/0000000019
# ...
